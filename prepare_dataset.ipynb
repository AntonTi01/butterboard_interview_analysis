# %%
def process_speaker_segments(input_file, output_file):
    merged_segments = []

    with open(input_file, "r") as file:
        lines = file.readlines()

    for line in lines:
        parts = line.strip().split()
        start_time = float(parts[0].split("=")[1][:-1])  # Извлекаем число без "s"
        stop_time = float(parts[1].split("=")[1][:-1])
        speaker = parts[2]  # Полное имя спикера

        # Убираем строки, где время старта совпадает со временем стопа
        if start_time == stop_time:
            continue

        # Если список пуст или спикер изменился, добавляем новый интервал
        if not merged_segments or merged_segments[-1][2] != speaker:
            merged_segments.append([start_time, stop_time, speaker])
        else:
            # Если разница между stop предыдущего и start текущего <= 0.1, объединяем интервалы
            if abs(merged_segments[-1][1] - start_time) <= 0.1:
                merged_segments[-1][1] = stop_time
            else:
                merged_segments.append([start_time, stop_time, speaker])

    # Фильтруем интервалы, оставляя только те, у которых продолжительность > 1 сек
    filtered_segments = [seg for seg in merged_segments if seg[1] - seg[0] > 1.0]

    # Дополнительное объединение, если спикер совпадает (объединяем соседние интервалы)
    final_segments = []
    for seg in filtered_segments:
        if not final_segments or final_segments[-1][2] != seg[2]:
            final_segments.append(seg)
        else:
            final_segments[-1][1] = seg[1]  # Расширяем предыдущий интервал

    # Сохраняем результат
    with open(output_file, "w") as file:
        for start, stop, speaker in final_segments:
            file.write(f"start={start:.1f}s stop={stop:.1f}s {speaker}\n")
    
    print(f"Обработанные интервалы сохранены в {output_file}")

# Пути к файлам в Jupyter Notebook
input_path = "results/diarization/interview_2.txt"
output_path = "results/diarization/interview_2_merged.txt"

process_speaker_segments(input_path, output_path)
with open(output_path, "r") as file:
    print(file.read())
# Out:
# Обработанные интервалы сохранены в results/diarization/interview_2_merged.txt
# start=0.0s stop=3.8s speaker_SPEAKER_01
# start=3.8s stop=5.5s speaker_SPEAKER_00
# start=5.4s stop=10.0s speaker_SPEAKER_01
# start=10.3s stop=14.3s speaker_SPEAKER_03
# start=14.8s stop=24.7s speaker_SPEAKER_01
# start=28.2s stop=50.5s speaker_SPEAKER_02
# start=51.1s stop=127.8s speaker_SPEAKER_00
# start=127.1s stop=131.8s speaker_SPEAKER_02
# start=134.2s stop=156.4s speaker_SPEAKER_00
# start=160.1s stop=171.5s speaker_SPEAKER_02
# start=172.0s stop=204.9s speaker_SPEAKER_00
# start=204.0s stop=207.0s speaker_SPEAKER_02
# start=207.3s stop=208.7s speaker_SPEAKER_00
# start=208.8s stop=217.7s speaker_SPEAKER_02
# start=218.3s stop=239.1s speaker_SPEAKER_00
# start=241.5s stop=246.9s speaker_SPEAKER_02
# start=247.9s stop=261.0s speaker_SPEAKER_00
# start=263.0s stop=271.7s speaker_SPEAKER_02
# start=271.6s stop=298.6s speaker_SPEAKER_00
# start=300.2s stop=313.0s speaker_SPEAKER_02
# start=314.0s stop=362.2s speaker_SPEAKER_00
# start=364.3s stop=372.5s speaker_SPEAKER_02
# start=373.2s stop=398.8s speaker_SPEAKER_00
# start=401.4s stop=410.0s speaker_SPEAKER_02
# start=410.4s stop=463.5s speaker_SPEAKER_00
# start=467.2s stop=509.3s speaker_SPEAKER_02
# start=509.9s stop=535.8s speaker_SPEAKER_00
# start=537.9s stop=543.4s speaker_SPEAKER_02
# start=544.5s stop=555.4s speaker_SPEAKER_00
# start=554.6s stop=557.0s speaker_SPEAKER_02
# start=557.3s stop=570.4s speaker_SPEAKER_00
# start=566.4s stop=567.9s speaker_SPEAKER_01
# start=572.8s stop=597.8s speaker_SPEAKER_00
# start=599.3s stop=605.0s speaker_SPEAKER_02
# start=607.1s stop=616.6s speaker_SPEAKER_00
# start=617.0s stop=625.9s speaker_SPEAKER_02
# start=627.0s stop=642.4s speaker_SPEAKER_00
# start=643.7s stop=646.9s speaker_SPEAKER_02
# start=647.0s stop=655.4s speaker_SPEAKER_00
# start=659.7s stop=662.5s speaker_SPEAKER_02
# start=665.6s stop=714.4s speaker_SPEAKER_03
# start=714.7s stop=716.0s speaker_SPEAKER_05
# start=716.8s stop=771.3s speaker_SPEAKER_03
# start=773.8s stop=826.9s speaker_SPEAKER_00
# start=828.2s stop=846.6s speaker_SPEAKER_03
# start=848.6s stop=883.9s speaker_SPEAKER_00
# start=885.4s stop=944.1s speaker_SPEAKER_03
# start=946.4s stop=947.6s speaker_SPEAKER_02
# start=947.9s stop=951.9s speaker_SPEAKER_03
# start=953.1s stop=955.3s speaker_SPEAKER_00
# start=954.9s stop=960.0s speaker_SPEAKER_03
# start=963.1s stop=966.1s speaker_SPEAKER_00
# start=967.6s stop=968.7s speaker_SPEAKER_03
# start=969.6s stop=984.5s speaker_SPEAKER_00
# start=986.3s stop=1003.2s speaker_SPEAKER_03
# start=1005.4s stop=1009.9s speaker_SPEAKER_00
# start=1011.7s stop=1014.2s speaker_SPEAKER_02
# start=1015.2s stop=1048.5s speaker_SPEAKER_00
# start=1050.6s stop=1060.2s speaker_SPEAKER_03
# start=1062.0s stop=1064.8s speaker_SPEAKER_00
# start=1070.7s stop=1076.2s speaker_SPEAKER_03
# start=1077.5s stop=1082.3s speaker_SPEAKER_00
# start=1087.6s stop=1091.8s speaker_SPEAKER_03
# start=1089.5s stop=1091.7s speaker_SPEAKER_05
# start=1092.0s stop=1108.3s speaker_SPEAKER_03
# start=1112.2s stop=1122.4s speaker_SPEAKER_02
# start=1123.0s stop=1186.7s speaker_SPEAKER_00
# start=1185.2s stop=1192.8s speaker_SPEAKER_03
# start=1193.2s stop=1219.0s speaker_SPEAKER_00
# start=1220.1s stop=1227.5s speaker_SPEAKER_03
# start=1227.9s stop=1229.5s speaker_SPEAKER_00
# start=1228.3s stop=1243.2s speaker_SPEAKER_03
# start=1243.9s stop=1250.9s speaker_SPEAKER_00
# start=1252.4s stop=1280.2s speaker_SPEAKER_03
# start=1280.6s stop=1342.8s speaker_SPEAKER_00
# start=1350.5s stop=1352.1s speaker_SPEAKER_03
# start=1355.3s stop=1365.8s speaker_SPEAKER_02
# start=1366.2s stop=1427.4s speaker_SPEAKER_00
# start=1430.2s stop=1437.2s speaker_SPEAKER_02
# start=1437.7s stop=1456.4s speaker_SPEAKER_00
# start=1457.1s stop=1466.2s speaker_SPEAKER_02
# start=1465.4s stop=1474.3s speaker_SPEAKER_00
# start=1476.0s stop=1494.1s speaker_SPEAKER_02
# start=1495.4s stop=1516.7s speaker_SPEAKER_00
# start=1518.1s stop=1547.8s speaker_SPEAKER_02
# start=1548.4s stop=1579.9s speaker_SPEAKER_00
# start=1582.0s stop=1599.3s speaker_SPEAKER_02
# start=1599.6s stop=1631.5s speaker_SPEAKER_00
# start=1633.5s stop=1642.8s speaker_SPEAKER_02
# start=1643.1s stop=1651.2s speaker_SPEAKER_00
# start=1652.5s stop=1655.2s speaker_SPEAKER_02
# start=1655.5s stop=1668.2s speaker_SPEAKER_00
# start=1670.5s stop=1678.0s speaker_SPEAKER_02
# start=1678.8s stop=1689.3s speaker_SPEAKER_00
# start=1693.2s stop=1717.0s speaker_SPEAKER_02
# start=1718.2s stop=1754.6s speaker_SPEAKER_00
# start=1756.3s stop=1765.6s speaker_SPEAKER_02
# start=1766.7s stop=1775.2s speaker_SPEAKER_00
# start=1775.4s stop=1778.2s speaker_SPEAKER_02
# start=1778.4s stop=1794.4s speaker_SPEAKER_00
# start=1795.1s stop=1803.3s speaker_SPEAKER_02
# start=1804.0s stop=1806.8s speaker_SPEAKER_00
# start=1808.3s stop=1817.3s speaker_SPEAKER_02
# start=1818.0s stop=1843.2s speaker_SPEAKER_00
# start=1846.7s stop=1850.2s speaker_SPEAKER_02
# start=1852.0s stop=1859.8s speaker_SPEAKER_03
# start=1867.5s stop=1875.2s speaker_SPEAKER_02
# start=1875.7s stop=1888.0s speaker_SPEAKER_00
# start=1890.3s stop=1893.7s speaker_SPEAKER_02
# start=1894.3s stop=1975.8s speaker_SPEAKER_00
# start=1976.4s stop=1982.5s speaker_SPEAKER_02
# start=1983.4s stop=2030.3s speaker_SPEAKER_00
# start=2032.3s stop=2048.5s speaker_SPEAKER_02
# start=2050.3s stop=2089.3s speaker_SPEAKER_00
# start=2088.7s stop=2094.9s speaker_SPEAKER_02
# start=2095.6s stop=2116.1s speaker_SPEAKER_00
# start=2118.7s stop=2121.1s speaker_SPEAKER_03
# start=2123.2s stop=2146.1s speaker_SPEAKER_00
# start=2150.1s stop=2155.9s speaker_SPEAKER_02
# start=2156.5s stop=2170.3s speaker_SPEAKER_00
# start=2174.9s stop=2212.0s speaker_SPEAKER_02
# start=2213.2s stop=2262.5s speaker_SPEAKER_00
# start=2262.8s stop=2286.2s speaker_SPEAKER_02
# start=2288.4s stop=2302.2s speaker_SPEAKER_00
# start=2301.4s stop=2311.3s speaker_SPEAKER_02
# start=2311.0s stop=2315.4s speaker_SPEAKER_00
# start=2315.6s stop=2317.7s speaker_SPEAKER_02
# start=2322.5s stop=2336.1s speaker_SPEAKER_00
# start=2337.6s stop=2343.9s speaker_SPEAKER_02
# start=2345.3s stop=2364.0s speaker_SPEAKER_00
# start=2363.4s stop=2365.1s speaker_SPEAKER_02
# start=2365.4s stop=2391.5s speaker_SPEAKER_00
# start=2392.5s stop=2398.0s speaker_SPEAKER_02
# start=2398.5s stop=2414.3s speaker_SPEAKER_00
# start=2415.5s stop=2419.2s speaker_SPEAKER_02
# start=2419.7s stop=2429.7s speaker_SPEAKER_03
# start=2431.8s stop=2439.1s speaker_SPEAKER_00
# start=2440.7s stop=2466.5s speaker_SPEAKER_03
# start=2467.7s stop=2489.0s speaker_SPEAKER_00
# start=2489.0s stop=2505.7s speaker_SPEAKER_03
# start=2507.0s stop=2509.7s speaker_SPEAKER_00
# start=2510.3s stop=2521.6s speaker_SPEAKER_03
# start=2522.1s stop=2534.4s speaker_SPEAKER_00
# start=2534.0s stop=2535.1s speaker_SPEAKER_04
# start=2535.0s stop=2543.7s speaker_SPEAKER_00
# start=2543.9s stop=2584.7s speaker_SPEAKER_03
# start=2588.4s stop=2602.5s speaker_SPEAKER_02
# start=2603.1s stop=2690.3s speaker_SPEAKER_00
# start=2692.6s stop=2699.8s speaker_SPEAKER_02
# start=2700.9s stop=2718.5s speaker_SPEAKER_00
# start=2720.6s stop=2722.1s speaker_SPEAKER_02
# start=2721.7s stop=2733.2s speaker_SPEAKER_00
# start=2733.8s stop=2738.5s speaker_SPEAKER_02
# start=2739.6s stop=2744.9s speaker_SPEAKER_00
# start=2744.4s stop=2746.2s speaker_SPEAKER_02
# start=2746.2s stop=2772.1s speaker_SPEAKER_00
# start=2773.4s stop=2776.5s speaker_SPEAKER_02
# start=2777.8s stop=2785.6s speaker_SPEAKER_00
# start=2786.2s stop=2798.6s speaker_SPEAKER_02
# start=2798.8s stop=2824.0s speaker_SPEAKER_00
# start=2826.6s stop=2831.9s speaker_SPEAKER_03
# start=2832.2s stop=2851.3s speaker_SPEAKER_00
# start=2852.0s stop=2860.9s speaker_SPEAKER_03
# start=2862.5s stop=2880.6s speaker_SPEAKER_00
# start=2876.9s stop=2896.0s speaker_SPEAKER_03
# start=2895.0s stop=2904.4s speaker_SPEAKER_00
# start=2904.9s stop=2912.9s speaker_SPEAKER_03
# start=2912.6s stop=2913.8s speaker_SPEAKER_05
# start=2913.4s stop=2931.3s speaker_SPEAKER_03
# start=2931.3s stop=2948.1s speaker_SPEAKER_02
# start=2948.5s stop=2992.6s speaker_SPEAKER_00
# start=2994.3s stop=3024.5s speaker_SPEAKER_02
# start=3026.0s stop=3079.7s speaker_SPEAKER_00
# start=3078.2s stop=3097.2s speaker_SPEAKER_03
# start=3097.5s stop=3116.1s speaker_SPEAKER_00
# start=3114.4s stop=3116.6s speaker_SPEAKER_02
# start=3116.6s stop=3123.9s speaker_SPEAKER_00
# start=3125.5s stop=3127.6s speaker_SPEAKER_02
# start=3127.6s stop=3138.8s speaker_SPEAKER_00
# start=3140.6s stop=3144.9s speaker_SPEAKER_02
# start=3145.5s stop=3172.0s speaker_SPEAKER_00
# start=3172.9s stop=3183.1s speaker_SPEAKER_02
# start=3189.1s stop=3199.7s speaker_SPEAKER_00
# start=3200.3s stop=3207.4s speaker_SPEAKER_02
# start=3207.7s stop=3212.5s speaker_SPEAKER_00
# start=3213.8s stop=3239.1s speaker_SPEAKER_02
# start=3239.6s stop=3276.3s speaker_SPEAKER_00
# start=3277.4s stop=3291.0s speaker_SPEAKER_02
# start=3291.0s stop=3320.7s speaker_SPEAKER_00
# start=3319.7s stop=3322.9s speaker_SPEAKER_02
# start=3323.6s stop=3332.0s speaker_SPEAKER_00
# start=3334.2s stop=3340.9s speaker_SPEAKER_02
# start=3341.1s stop=3351.6s speaker_SPEAKER_00
# start=3355.2s stop=3363.7s speaker_SPEAKER_02
# start=3364.4s stop=3381.5s speaker_SPEAKER_00
# start=3382.6s stop=3384.9s speaker_SPEAKER_02
# start=3385.6s stop=3396.6s speaker_SPEAKER_00
# start=3397.3s stop=3403.5s speaker_SPEAKER_02
# start=3404.1s stop=3411.2s speaker_SPEAKER_00
# start=3410.8s stop=3419.7s speaker_SPEAKER_03
# start=3423.8s stop=3425.3s speaker_SPEAKER_02
# start=3425.6s stop=3444.5s speaker_SPEAKER_00
# start=3445.2s stop=3449.7s speaker_SPEAKER_02
# start=3451.2s stop=3459.3s speaker_SPEAKER_00
# start=3459.6s stop=3465.8s speaker_SPEAKER_02
# start=3466.5s stop=3473.2s speaker_SPEAKER_00
# start=3473.6s stop=3479.2s speaker_SPEAKER_02
# start=3479.0s stop=3482.3s speaker_SPEAKER_00
# start=3481.4s stop=3495.2s speaker_SPEAKER_02
# start=3494.0s stop=3497.2s speaker_SPEAKER_00
# start=3498.5s stop=3504.0s speaker_SPEAKER_03
# start=3507.0s stop=3519.6s speaker_SPEAKER_00
# start=3521.5s stop=3550.5s speaker_SPEAKER_03
# start=3551.3s stop=3570.3s speaker_SPEAKER_02
# start=3555.8s stop=3590.6s speaker_SPEAKER_03
# start=3589.8s stop=3593.5s speaker_SPEAKER_02
# start=3595.4s stop=3600.9s speaker_SPEAKER_03
# start=3604.9s stop=3667.8s speaker_SPEAKER_00
# start=3673.2s stop=3682.1s speaker_SPEAKER_03
# start=3682.7s stop=3694.7s speaker_SPEAKER_00
# start=3698.4s stop=3708.3s speaker_SPEAKER_03
# start=3709.6s stop=3717.0s speaker_SPEAKER_00
# start=3716.0s stop=3746.7s speaker_SPEAKER_03
# start=3747.6s stop=3759.5s speaker_SPEAKER_02
# start=3759.9s stop=3786.4s speaker_SPEAKER_00
# start=3787.8s stop=3791.8s speaker_SPEAKER_02
# start=3792.9s stop=3794.5s speaker_SPEAKER_00
# start=3796.6s stop=3803.3s speaker_SPEAKER_02
# start=3803.3s stop=3809.3s speaker_SPEAKER_00
# start=3811.1s stop=3816.2s speaker_SPEAKER_02
# start=3817.9s stop=3832.5s speaker_SPEAKER_00
# start=3831.1s stop=3840.6s speaker_SPEAKER_02
# start=3843.0s stop=3847.3s speaker_SPEAKER_00
# start=3849.6s stop=3854.8s speaker_SPEAKER_02
# start=3855.2s stop=3863.8s speaker_SPEAKER_00
# start=3864.9s stop=3897.4s speaker_SPEAKER_02
# start=3900.2s stop=3905.5s speaker_SPEAKER_00
# start=3908.1s stop=3924.2s speaker_SPEAKER_02
# start=3926.0s stop=3927.8s speaker_SPEAKER_00
# start=3930.4s stop=3933.7s speaker_SPEAKER_02
# start=3933.2s stop=3946.3s speaker_SPEAKER_00
# start=3948.7s stop=3959.1s speaker_SPEAKER_02
# start=3960.0s stop=3969.7s speaker_SPEAKER_00
# start=3970.5s stop=3973.6s speaker_SPEAKER_02
# start=3973.9s stop=3996.1s speaker_SPEAKER_00
# start=3997.4s stop=4001.8s speaker_SPEAKER_02
# start=4003.1s stop=4007.9s speaker_SPEAKER_00
# start=4007.9s stop=4009.8s speaker_SPEAKER_02
# start=4009.2s stop=4026.2s speaker_SPEAKER_00
# start=4025.4s stop=4033.7s speaker_SPEAKER_02
# start=4035.2s stop=4045.4s speaker_SPEAKER_00
# start=4047.6s stop=4054.9s speaker_SPEAKER_02
# start=4055.1s stop=4056.3s speaker_SPEAKER_00
# start=4055.3s stop=4065.9s speaker_SPEAKER_02
# start=4067.1s stop=4082.0s speaker_SPEAKER_00
# start=4083.6s stop=4086.0s speaker_SPEAKER_02
# start=4086.3s stop=4113.4s speaker_SPEAKER_00
# start=4116.4s stop=4119.2s speaker_SPEAKER_02
# start=4121.6s stop=4131.3s speaker_SPEAKER_00
# start=4133.9s stop=4138.0s speaker_SPEAKER_02
# start=4143.2s stop=4149.1s speaker_SPEAKER_03
# start=4150.4s stop=4157.6s speaker_SPEAKER_00
# start=4158.0s stop=4163.9s speaker_SPEAKER_03
# start=4164.3s stop=4223.7s speaker_SPEAKER_00
# start=4223.2s stop=4233.5s speaker_SPEAKER_02
# start=4233.5s stop=4251.2s speaker_SPEAKER_00
# start=4253.1s stop=4258.9s speaker_SPEAKER_02
# start=4259.2s stop=4294.0s speaker_SPEAKER_00
# start=4299.7s stop=4301.5s speaker_SPEAKER_03
# start=4304.1s stop=4305.9s speaker_SPEAKER_02
# start=4307.4s stop=4320.7s speaker_SPEAKER_00
# start=4323.2s stop=4327.3s speaker_SPEAKER_02
# start=4330.4s stop=4337.1s speaker_SPEAKER_03
# start=4338.8s stop=4340.3s speaker_SPEAKER_02
# start=4340.8s stop=4347.5s speaker_SPEAKER_03
# start=4348.2s stop=4369.0s speaker_SPEAKER_00
# start=4348.3s stop=4349.7s speaker_SPEAKER_03
# start=4369.0s stop=4400.3s speaker_SPEAKER_00
# start=4403.0s stop=4407.4s speaker_SPEAKER_03
# start=4403.6s stop=4410.1s speaker_SPEAKER_00
# start=4411.3s stop=4442.1s speaker_SPEAKER_03
# start=4440.7s stop=4462.4s speaker_SPEAKER_00
# start=4460.9s stop=4508.3s speaker_SPEAKER_03
# start=4509.3s stop=4545.5s speaker_SPEAKER_00
# start=4546.9s stop=4549.8s speaker_SPEAKER_03
# start=4549.2s stop=4560.1s speaker_SPEAKER_00
# start=4564.2s stop=4568.9s speaker_SPEAKER_03
# start=4569.2s stop=4571.6s speaker_SPEAKER_00
# start=4571.3s stop=4573.2s speaker_SPEAKER_03
# start=4574.3s stop=4590.5s speaker_SPEAKER_00
# start=4591.2s stop=4594.5s speaker_SPEAKER_03
# start=4595.5s stop=4598.6s speaker_SPEAKER_00
# start=4599.7s stop=4613.9s speaker_SPEAKER_03
# start=4615.9s stop=4620.0s speaker_SPEAKER_00
# start=4622.8s stop=4631.0s speaker_SPEAKER_03
# start=4631.5s stop=4633.9s speaker_SPEAKER_00
# start=4636.3s stop=4646.5s speaker_SPEAKER_03
# start=4647.6s stop=4662.1s speaker_SPEAKER_00
# start=4662.8s stop=4681.7s speaker_SPEAKER_03
# start=4681.9s stop=4689.5s speaker_SPEAKER_00
# start=4695.7s stop=4698.6s speaker_SPEAKER_03
# start=4699.5s stop=4702.2s speaker_SPEAKER_02
# start=4702.7s stop=4707.7s speaker_SPEAKER_03
# start=4709.0s stop=4720.7s speaker_SPEAKER_01

# %%
import re

def convert_seconds_to_timestamp(seconds):
    """Преобразует секунды в формат HH:MM:SS,SSS"""
    hours = int(seconds // 3600)
    minutes = int((seconds % 3600) // 60)
    sec = int(seconds % 60)
    millisec = int((seconds % 1) * 1000)
    return f"{hours:02}:{minutes:02}:{sec:02},{millisec:03}"

def convert_diarization_file(input_path, output_path):
    """
    Читает файл диаризации, преобразует время в формат HH:MM:SS,SSS и сохраняет новый файл.
    """
    with open(input_path, "r") as file:
        lines = file.readlines()

    converted_lines = []
    for line in lines:
        match = re.match(r"start=([\d\.]+)s stop=([\d\.]+)s (speaker_SPEAKER_\d+)", line.strip())
        if match:
            start_seconds = float(match.group(1))
            stop_seconds = float(match.group(2))
            speaker = match.group(3)

            start_timestamp = convert_seconds_to_timestamp(start_seconds)
            stop_timestamp = convert_seconds_to_timestamp(stop_seconds)

            converted_lines.append(f"{start_timestamp} - {stop_timestamp} - {speaker}")

    # Сохраняем преобразованный файл
    with open(output_path, "w") as file:
        for line in converted_lines:
            file.write(line + "\n")

    print(f"Файл с преобразованным временем сохранён в {output_path}")

# Пути к файлам
input_file = "results/diarization/interview_2_merged.txt"
output_file = "results/diarization/interview_2_converted.txt"

# Запуск функции
convert_diarization_file(input_file, output_file)
# Out:
# Файл с преобразованным временем сохранён в results/diarization/interview_2_converted.txt
